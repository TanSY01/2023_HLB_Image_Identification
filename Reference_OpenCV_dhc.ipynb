# %% [markdown]
# <a href="https://colab.research.google.com/github/TanSY01/2023_HLB_Image_Identification/blob/main/Reference_OpenCV_dhc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !wget http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_train.json
# !wget http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_val.json
# !wget http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_sample_submit_A.csv
# Out:
# --2022-05-01 11:44:58--  http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_train.json
# Resolving tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)... 118.31.232.194
# Connecting to tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)|118.31.232.194|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3310747 (3.2M) [application/json]
# Saving to: ‘mchar_train.json.2’
#
# mchar_train.json.2    1%[                    ]  52.76K  25.2KB/s               ^C
# --2022-05-01 11:45:01--  http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_val.json
# Resolving tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)... 118.31.232.194
# Connecting to tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)|118.31.232.194|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1077984 (1.0M) [application/json]
# Saving to: ‘mchar_val.json.2’
#
# mchar_val.json.2    100%[===================>]   1.03M   383KB/s    in 2.8s
#
# 2022-05-01 11:45:05 (383 KB/s) - ‘mchar_val.json.2’ saved [1077984/1077984]
#
# --2022-05-01 11:45:05--  http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_sample_submit_A.csv
# Resolving tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)... 118.31.232.194
# Connecting to tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)|118.31.232.194|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 520020 (508K) [text/csv]
# Saving to: ‘mchar_sample_submit_A.csv.2’
#
# mchar_sample_submit 100%[===================>] 507.83K   161KB/s    in 3.2s
#
# 2022-05-01 11:45:09 (161 KB/s) - ‘mchar_sample_submit_A.csv.2’ saved [520020/520020]

# %%
# !wget http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_train.zip
# Out:
# --2022-05-01 09:52:48--  http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_train.zip
# Resolving tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)... 118.31.232.194
# Connecting to tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)|118.31.232.194|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 362711501 (346M) [application/zip]
# Saving to: ‘mchar_train.zip’
#
# mchar_train.zip     100%[===================>] 345.91M  1.65MB/s    in 2m 39s
#
# 2022-05-01 09:55:27 (2.18 MB/s) - ‘mchar_train.zip’ saved [362711501/362711501]

# %%
# !wget http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_val.zip
# Out:
# --2022-05-01 09:55:27--  http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_val.zip
# Resolving tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)... 118.31.232.194
# Connecting to tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)|118.31.232.194|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 209887177 (200M) [application/zip]
# Saving to: ‘mchar_val.zip’
#
# mchar_val.zip       100%[===================>] 200.16M  3.23MB/s    in 71s
#
# 2022-05-01 09:56:39 (2.83 MB/s) - ‘mchar_val.zip’ saved [209887177/209887177]

# %%
# !wget http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_test_a.zip
# Out:
# --2022-05-01 09:56:39--  http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_test_a.zip
# Resolving tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)... 118.31.232.194
# Connecting to tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)|118.31.232.194|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 388603696 (371M) [application/zip]
# Saving to: ‘mchar_test_a.zip’
#
# mchar_test_a.zip    100%[===================>] 370.60M  4.80MB/s    in 93s
#
# 2022-05-01 09:58:13 (3.96 MB/s) - ‘mchar_test_a.zip’ saved [388603696/388603696]

# %%
# !unzip /content/mchar_test_a.zip
# !unzip /content/mchar_train.zip
# !unzip /content/mchar_val.zip
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating
#   inflating: mchar_val/006923.png
#   inflating: __MACOSX/mchar_val/._006923.png
#   inflating: mchar_val/001094.png
#   inflating: __MACOSX/mchar_val/._001094.png
#   inflating: mchar_val/003683.png
#   inflating: __MACOSX/mchar_val/._003683.png
#   inflating: mchar_val/002589.png
#   inflating: __MACOSX/mchar_val/._002589.png
#   inflating: mchar_val/003697.png
#   inflating: __MACOSX/mchar_val/._003697.png
#   inflating: mchar_val/006937.png
#   inflating: __MACOSX/mchar_val/._006937.png
#   inflating: mchar_val/001080.png
#   inflating: __MACOSX/mchar_val/._001080.png
#   inflating: mchar_val/006089.png
#   inflating: __MACOSX/mchar_val/._006089.png
#   inflating: mchar_val/007397.png
#   inflating: __MACOSX/mchar_val/._007397.png
#   inflating: mchar_val/004846.png
#   inflating: __MACOSX/mchar_val/._004846.png
#   inflating: mchar_val/005580.png
#   inflating: __MACOSX/mchar_val/._005580.png
#   inflating: mchar_val/009392.png
#   inflating: __MACOSX/mchar_val/._009392.png
#   inflating: mchar_val/001916.png
#   inflating: __MACOSX/mchar_val/._001916.png
#   inflating: mchar_val/003867.png
#   inflating: __MACOSX/mchar_val/._003867.png
#   inflating: mchar_val/008932.png
#   inflating: __MACOSX/mchar_val/._008932.png
#   inflating: mchar_val/008926.png
#   inflating: __MACOSX/mchar_val/._008926.png
#   inflating: mchar_val/003873.png
#   inflating: __MACOSX/mchar_val/._003873.png
#   inflating: mchar_val/009386.png
#   inflating: __MACOSX/mchar_val/._009386.png
#   inflating: mchar_val/008098.png
#   inflating: __MACOSX/mchar_val/._008098.png
#   inflating: mchar_val/001902.png
#   inflating: __MACOSX/mchar_val/._001902.png
#   inflating: __MACOSX/._mchar_val

# %%
data_dir = {
    'train_data': '/content/mchar_train/',
    'val_data': '/content/mchar_val/',
    'test_data': '/content/mchar_test_a/',
    'train_label': '/content/mchar_train.json',
    'val_label': '/content/mchar_val.json',
    'submit_file': '/content/mchar_sample_submit_A.csv'
}

# %%
import os
from glob import glob
import torch as t
from PIL import Image
import torch.nn as nn
from tqdm.auto import tqdm
from torchvision import transforms
from torchvision.utils import save_image, make_grid
from torch.optim import SGD
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts, MultiStepLR
from torch.utils.data import DataLoader, Dataset, WeightedRandomSampler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patch
import torch.nn.functional as F
import json
from torchvision.models.mobilenet import mobilenet_v2
from torchvision.models.resnet import resnet50, resnet34,resnet18
from torchsummary import summary
import random
from torchvision.models.mobilenet import MobileNetV2

# %%
os.getcwd()
# Out:
# '/content'

# %%
#超参数设定
class Config:

  batch_size = 64

  lr = 1e-3

  momentum = 0.9

  weights_decay = 1e-4

  class_num = 11

  eval_interval = 1

  checkpoint_interval = 1

  print_interval = 50

  checkpoints = '/content/checkpionts/'#这个需要自己创建一个文件夹用来储存权重

  pretrained = None#'/content/checkpionts/epoch-resnet18-52-bn-acc-73.86.pth' #'/content/NDataset/checkpionts/epoch-mobeilenet-91-bn-acc-72.23.pth'

  start_epoch = 52

  epoches = 100

  smooth = 0.1

  erase_prob = 0.5

config = Config()

# %%
class DigitsDataset(Dataset):
    """

    DigitsDataset

    Params:
      data_dir(string): data directory

      label_path(string): label path

      aug(bool): wheather do image augmentation, default: True
    """

    def __init__(self, mode='train', size=(128, 256), aug=True):
        super(DigitsDataset, self).__init__()

        self.aug = aug
        self.size = size
        self.mode = mode
        self.width = 224
        # self.weights = np.array(list(label__nums_summary().values()))
        # self.weights = (np.sum(self.weights) - self.weights) / self.weights
        # self.weights = t.from_numpy(self.weights.to_list().append(1)).float()
        self.batch_count = 0
        if mode == 'test':
            self.imgs = glob(data_dir['test_data'] + '*.png')
            self.labels = None
        else:
            labels = json.load(open(data_dir['%s_label' % mode], 'r'))

            imgs = glob(data_dir['%s_data' % mode] + '*.png')
            self.imgs = [(img, labels[os.path.split(img)[-1]]) for img in imgs \
                         if os.path.split(img)[-1] in labels]

    def __getitem__(self, idx):
        if self.mode != 'test':
            img, label = self.imgs[idx]
        else:
            img = self.imgs[idx]
            label = None
        img = Image.open(img)
        trans0 = [
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ]
        min_size = self.size[0] if (img.size[1] / self.size[0]) < ((img.size[0] / self.size[1])) else self.size[1]
        trans1 = [
            transforms.Resize(128),
            transforms.CenterCrop((128, self.width))
        ]
        if self.aug:
            trans1.extend([
                transforms.ColorJitter(0.1, 0.1, 0.1),
                transforms.RandomGrayscale(0.1),
                transforms.RandomAffine(15, translate=(0.05, 0.1), shear=5)
            ])
        trans1.extend(trans0)
        if self.mode != 'test':
            return transforms.Compose(trans1)(img), t.tensor(
                label['label'][:4] + (4 - len(label['label'])) * [10]).long()
        else:
            # trans1.append(transforms.RandomErasing(scale=(0.02, 0.1)))
            return transforms.Compose(trans1)(img), self.imgs[idx]

    def __len__(self):
        return len(self.imgs)

    def collect_fn(self, batch):
        imgs, labels = zip(*batch)
        if self.mode == 'train':
            if self.batch_count > 0 and self.batch_count % 10 == 0:
                self.width = random.choice(range(224, 256, 16))

        self.batch_count += 1
        return t.stack(imgs).float(), t.stack(labels)

# %%
class DigitsMobilenet(nn.Module):

  def __init__(self, class_num=11):
    super(DigitsMobilenet, self).__init__()

    self.net = mobilenet_v2(pretrained=True).features
    # self.net.classifier = nn.Identity()
    self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
    self.bn = nn.BatchNorm1d(1280)
    self.fc1 = nn.Linear(1280, class_num)
    self.fc2 = nn.Linear(1280, class_num)
    self.fc3 = nn.Linear(1280, class_num)
    self.fc4 = nn.Linear(1280, class_num)
    # self.fc5 = nn.Linear(1280, class_num)

  def forward(self, img):
    features = self.avgpool(self.net(img)).view(-1, 1280)
    features = self.bn(features)

    fc1 = self.fc1(features)
    fc2 = self.fc2(features)
    fc3 = self.fc3(features)
    fc4 = self.fc4(features)
    # fc5 = self.fc5(features)

    return fc1, fc2, fc3, fc4


class DigitsResnet18(nn.Module):

  def __init__(self, class_num=11):
    super(DigitsResnet18, self).__init__()
    self.net = resnet18(pretrained=True)
    self.net.fc = nn.Identity()
    # self.net = nn.Sequential(
    #     MobileNetV2(num_classes=class_num).features,
    #     nn.AdaptiveAvgPool2d((1, 1))
    # )
    self.bn = nn.BatchNorm1d(512)
    self.fc1 = nn.Linear(512, class_num)
    self.fc2 = nn.Linear(512, class_num)
    self.fc3 = nn.Linear(512, class_num)
    self.fc4 = nn.Linear(512, class_num)
    # self.fc5 = nn.Linear(512, class_num)

  def forward(self, img):
    features = self.net(img).squeeze()

    fc1 = self.fc1(features)
    fc2 = self.fc2(features)
    fc3 = self.fc3(features)
    fc4 = self.fc4(features)
    # fc5 = self.fc5(features)

    return fc1, fc2, fc3, fc4


class DigitsResnet50(nn.Module):
    def __init__(self, class_num=11):
        super(DigitsResnet50, self).__init__()

        # resnet18
        self.net = resnet50(pretrained=True)
        self.avgpool = nn.AdaptiveAvgPool2d(1)
        self.net = nn.Sequential(*list(self.net.children())[:-1])  # 去除最后一个fc layer
        self.cnn = self.net

        self.hd_fc1 = nn.Linear(2048, 128)  #512改成2048
        self.hd_fc2 = nn.Linear(2048, 128)
        self.hd_fc3 = nn.Linear(2048, 128)
        self.hd_fc4 = nn.Linear(2048, 128)
        # self.hd_fc5 = nn.Linear(512, 128)
        self.dropout_1 = nn.Dropout(0.25)
        self.dropout_2 = nn.Dropout(0.25)
        self.dropout_3 = nn.Dropout(0.25)
        self.dropout_4 = nn.Dropout(0.25)
        # self.dropout_5 = nn.Dropout(0.25)
        self.fc1 = nn.Linear(128, 11)
        self.fc2 = nn.Linear(128, 11)
        self.fc3 = nn.Linear(128, 11)
        self.fc4 = nn.Linear(128, 11)
        # self.fc5 = nn.Linear(128, 11)

    def forward(self, img):
        feat = self.cnn(img)
        feat = feat.view(feat.shape[0], -1)
        # feat = self.net(img).squeeze()

        feat1 = self.hd_fc1(feat)
        feat2 = self.hd_fc2(feat)
        feat3 = self.hd_fc3(feat)
        feat4 = self.hd_fc4(feat)
        # feat5 = self.hd_fc5(feat)
        feat1 = self.dropout_1(feat1)
        feat2 = self.dropout_2(feat2)
        feat3 = self.dropout_3(feat3)
        feat4 = self.dropout_4(feat4)
        # feat5 = self.dropout_5(feat5)

        c1 = self.fc1(feat1)
        c2 = self.fc2(feat2)
        c3 = self.fc3(feat3)
        c4 = self.fc4(feat4)
        # c5 = self.fc5(feat5)

        return c1, c2, c3, c4

# %%
class LabelSmoothEntropy(nn.Module):
    def __init__(self, smooth=0.1, class_weights=None, size_average='mean'):
        super(LabelSmoothEntropy, self).__init__()
        self.size_average = size_average
        self.smooth = smooth

        self.class_weights = class_weights

    def forward(self, preds, targets):

        lb_pos, lb_neg = 1 - self.smooth, self.smooth / (preds.shape[0] - 1)

        smoothed_lb = t.zeros_like(preds).fill_(lb_neg).scatter_(1, targets[:, None], lb_pos)

        log_soft = F.log_softmax(preds, dim=1)

        if self.class_weights is not None:
            loss = -log_soft * smoothed_lb * self.class_weights[None, :]

        else:
            loss = -log_soft * smoothed_lb

        loss = loss.sum(1)
        if self.size_average == 'mean':
            return loss.mean()

        elif self.size_average == 'sum':
            return loss.sum()
        else:
            raise NotImplementedError

# %%
class SnapShotBuilder():
    """

    Params:
      n_epoch(integer): total training epoches

      n_snap(integer): parameters of model saved times

    """

    def __init__(self, n_epoch, n_snap):
        self.n_epoch = n_epoch

        self.n_snap = n_snap

        pass

    def __call__(self):
        pass

    def _scheduler(self):
        pass

# %%
# 使用resnet
class Trainer:

    def __init__(self, val=True):

        self.device = t.device('cuda') if t.cuda.is_available() else t.device('cpu')

        self.train_set = DigitsDataset(mode='train')
        self.train_loader = DataLoader(self.train_set, batch_size=config.batch_size, shuffle=True, num_workers=8,
                                       pin_memory=True, \
                                       drop_last=True, collate_fn=self.train_set.collect_fn)

        if val:
            self.val_loader = DataLoader(DigitsDataset(mode='val', aug=False), batch_size=config.batch_size, \
                                         num_workers=8, pin_memory=True, drop_last=False)
        else:
            self.val_loader = None

#可以切换使用resnet或者Mobilenet
        # self.model = DigitsMobilenet(config.class_num).to(self.device)
        self.model = DigitsResnet18(config.class_num).to(self.device)

        self.criterion = LabelSmoothEntropy().to(self.device)

#optimizer可选择SGD或者Adam
        # self.optimizer = SGD(self.model.parameters(), lr=config.lr, momentum=config.momentum, weight_decay=config.weights_decay, nesterov=True)
        from torch.optim import Adam
        # self.optimizer = Adam(self.model.parameters(), lr=1e-3)
        self.optimizer = Adam(self.model.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0,
                              amsgrad=False)
#学习率调整
        # self.lr_scheduler = CosineAnnealingWarmRestarts(self.optimizer, 10, 2, eta_min=10e-5),eta_min=10e-4,10e-5
        self.lr_scheduler = CosineAnnealingWarmRestarts(self.optimizer, T_0=10, T_mult=2, eta_min=0)
        # self.lr_scheduler = (self.optimizer, [10, 20, 30], 0.5)
        self.best_acc = 0

#是否载入预训练模型
        if config.pretrained is not None:
            self.load_model(config.pretrained)
            # print('Load model from %s'%config.pretrained)
            if self.val_loader is not None:
                acc = self.eval()
            self.best_acc = acc
            print('Load model from %s, Eval Acc: %.2f' % (config.pretrained, acc * 100))

    def train(self):
        for epoch in range(config.start_epoch, config.epoches):
            acc = self.train_epoch(epoch)
            if (epoch + 1) % config.eval_interval == 0:
                print('Start Evaluation')
                if self.val_loader is not None:
                    acc = self.eval()
#保存最优模型
                if acc > self.best_acc:
                    os.makedirs(config.checkpoints, exist_ok=True)
                    save_path = config.checkpoints + 'epoch-resnet18-%d-bn-acc-%.2f.pth' % (epoch + 1, acc * 100)
                    self.save_model(save_path)
                    print('%s saved successfully...' % save_path)
                    self.best_acc = acc

    def train_epoch(self, epoch):
        total_loss = 0
        corrects = 0
        tbar = tqdm(self.train_loader)
        self.model.train()
        for i, (img, label) in enumerate(tbar):
            # print(img.shape)
            img = img.to(self.device)
            label = label.to(self.device)
            self.optimizer.zero_grad()
            pred = self.model(img)
            loss = self.criterion(pred[0], label[:, 0]) + \
                   self.criterion(pred[1], label[:, 1]) + \
                   self.criterion(pred[2], label[:, 2]) + \
                   self.criterion(pred[3], label[:, 3]) \
                # + self.criterion(pred[4], label[:, 4])
            total_loss += loss.item()
            loss.backward()
            self.optimizer.step()
            temp = t.stack([ \
                pred[0].argmax(1) == label[:, 0], \
                pred[1].argmax(1) == label[:, 1], \
                pred[2].argmax(1) == label[:, 2], \
                pred[3].argmax(1) == label[:, 3], ], dim=1)

            corrects += t.all(temp, dim=1).sum().item()
            tbar.set_description(
                'loss: %.3f, acc: %.3f' % (loss / (i + 1), corrects * 100 / ((i + 1) * config.batch_size)))
            if (i + 1) % config.print_interval == 0:
                self.lr_scheduler.step()

        return corrects * 100 / ((i + 1) * config.batch_size)

    def eval(self):
        self.model.eval()
        corrects = 0
        with t.no_grad():
            tbar = tqdm(self.val_loader)
            for i, (img, label) in enumerate(tbar):
                img = img.to(self.device)
                label = label.to(self.device)
                pred = self.model(img)
                # temp = t.stack([])
                temp = t.stack([
                    pred[0].argmax(1) == label[:, 0], \
                    pred[1].argmax(1) == label[:, 1], \
                    pred[2].argmax(1) == label[:, 2], \
                    pred[3].argmax(1) == label[:, 3], \
                    ], dim=1)

                corrects += t.all(temp, dim=1).sum().item()
                tbar.set_description('Val Acc: %.2f' % (corrects * 100 / ((i + 1) * config.batch_size)))
        self.model.train()
        return corrects / (len(self.val_loader) * config.batch_size)

    def save_model(self, save_path, save_opt=False, save_config=False):
        dicts = {}
        dicts['model'] = self.model.state_dict()
        if save_opt:
            dicts['opt'] = self.optimizer.state_dict()

        if save_config:
            dicts['config'] = {s: config.__getattribute__(s) for s in dir(config) if not s.startswith('_')}

        t.save(dicts, save_path)

    def load_model(self, load_path, changed=False, save_opt=False, save_config=False):

        dicts = t.load(load_path)
        if not changed:
            self.model.load_state_dict(dicts['model'])

        else:
            dicts = t.load(load_path)['model']

            keys = list(net.state_dict().keys())
            values = list(dicts.values())

            new_dicts = {k: v for k, v in zip(keys, values)}
            self.model.load_state_dict(new_dicts)

        if save_opt:
            self.optimizer.load_state_dict(dicts['opt'])

        if save_config:
            for k, v in dicts['config'].items():
                config.__setattr__(k, v)

# %%
trainer = Trainer()
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-f40a3b70617c> in <module>()
# ----> 1 trainer = Trainer()
#       2 trainer.train()
#
# <ipython-input-9-870b5164a577> in __init__(self, val)
#       6         self.device = t.device('cuda') if t.cuda.is_available() else t.device('cpu')
#       7
# ----> 8         self.train_set = DigitsDataset(mode='train')
#       9         self.train_loader = DataLoader(self.train_set, batch_size=config.batch_size, shuffle=True, num_workers=8,
#      10                                        pin_memory=True, \
#
# <ipython-input-6-145335554411> in __init__(self, mode, size, aug)
#      27             self.labels = None
#      28         else:
# ---> 29             labels = json.load(open(data_dir['%s_label' % mode], 'r'))
#      30
#      31             imgs = glob(data_dir['%s_data' % mode] + '*.png')
#
# NameError: name 'data_dir' is not defined

# %%
def predicts(model_path):
  test_loader = DataLoader(DigitsDataset(mode='test', aug=False), batch_size=config.batch_size, shuffle=False,\
                    num_workers=8, pin_memory=True, drop_last=False)
  results = []
  #因为这里使用了模型融合，所以如果你只是训练出一个模型进行预测，则要把另外一个模型注释掉
  ##mb_path = '/content/ckpionts/epoch-mobilenet-96-bn-acc-74.54.pth'
  res_path = '/content/checkpionts/epoch-resnet18-66-bn-acc-72.96.pth'
  ##mb_net = DigitsMobilenet().cuda()
  # dicts = t.load(mb_path)['model']
  # dicts.popitem()
  # dicts.popitem()
  ##mb_net.load_state_dict(t.load(mb_path)['model'])


  res_net = DigitsResnet18().cuda()
  res_net.load_state_dict(t.load(res_path)['model'])
  # print('Load model from %s successfully'%model_path)

  tbar = tqdm(test_loader)
  ##mb_net.eval()
  res_net.eval()
  with t.no_grad():
    for i, (img, img_names) in enumerate(tbar):
      img = img.cuda()
      #pred = mb_net(img)
      pred = res_net(img)
      #pred = [0.4 * a + 0.6 * b for a, b in zip(res_net(img), mb_net(img))]
      results += [[name, code] for name, code in zip(img_names, parse2class(pred))]

  # result.sort(key=results)
  results = sorted(results, key=lambda x: x[0])

  write2csv(results)
  return results



def parse2class(prediction):
  """

  Params:
    prediction(tuple of tensor):


  """
  ch1, ch2, ch3, ch4 = prediction

  char_list = [str(i) for i in range(10)]
  char_list.append('')


  ch1, ch2, ch3, ch4 = ch1.argmax(1), ch2.argmax(1), ch3.argmax(1), ch4.argmax(1)

  ch1, ch2, ch3, ch4 = [char_list[i.item()] for i in ch1], [char_list[i.item()] for i in ch2], \
                  [char_list[i.item()] for i in ch3], [char_list[i.item()] for i in ch4] \
                  # ，[char_list[i.item()] for i in ch5]

  # res = [c1+c2+c3+c4+c5 for c1, c2, c3, c4, c5 in zip(ch1, ch2, ch3, ch4, ch5)]
  res = [c1+c2+c3+c4 for c1, c2, c3, c4 in zip(ch1, ch2, ch3, ch4)]
  return res


def write2csv(results):
  """

  results(list):

  """
#定义输出文件
  df = pd.DataFrame(results, columns=['file_name', 'file_code'])
  df['file_name'] = df['file_name'].apply(lambda x: x.split('/')[-1])
  save_name = '/content/results-mb.csv'
  df.to_csv(save_name, sep=',', index=None)
  print('Results.saved to %s'%save_name)

# %%
predicts('/content/checkpionts/')
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0%|          | 0/625 [00:00<?, ?it/s]
# Results.saved to /content/results-mb.csv
# [['/content/mchar_test_a/000000.png', '199'],
#  ['/content/mchar_test_a/000001.png', '290'],
#  ['/content/mchar_test_a/000002.png', '113'],
#  ['/content/mchar_test_a/000003.png', '97'],
#  ['/content/mchar_test_a/000004.png', '63'],
#  ['/content/mchar_test_a/000005.png', '639'],
#  ['/content/mchar_test_a/000006.png', '126'],
#  ['/content/mchar_test_a/000007.png', '1475'],
#  ['/content/mchar_test_a/000008.png', '48'],
#  ['/content/mchar_test_a/000009.png', '118'],
#  ['/content/mchar_test_a/000010.png', '281'],
#  ['/content/mchar_test_a/000011.png', '610'],
#  ['/content/mchar_test_a/000012.png', '60'],
#  ['/content/mchar_test_a/000013.png', '772'],
#  ['/content/mchar_test_a/000014.png', '836'],
#  ['/content/mchar_test_a/000015.png', '40'],
#  ['/content/mchar_test_a/000016.png', '29'],
#  ['/content/mchar_test_a/000017.png', '60'],
#  ['/content/mchar_test_a/000018.png', '15'],
#  ['/content/mchar_test_a/000019.png', '804'],
#  ['/content/mchar_test_a/000020.png', '284'],
#  ['/content/mchar_test_a/000021.png', '14'],
#  ['/content/mchar_test_a/000022.png', '245'],
#  ['/content/mchar_test_a/000023.png', '2001'],
#  ['/content/mchar_test_a/000024.png', '374'],
#  ['/content/mchar_test_a/000025.png', '33'],
#  ['/content/mchar_test_a/000026.png', '11'],
#  ['/content/mchar_test_a/000027.png', '157'],
#  ['/content/mchar_test_a/000028.png', '98'],
#  ['/content/mchar_test_a/000029.png', '14'],
#  ['/content/mchar_test_a/000030.png', '226'],
#  ['/content/mchar_test_a/000031.png', '545'],
#  ['/content/mchar_test_a/000032.png', '72'],
#  ['/content/mchar_test_a/000033.png', '243'],
#  ['/content/mchar_test_a/000034.png', '217'],
#  ['/content/mchar_test_a/000035.png', '176'],
#  ['/content/mchar_test_a/000036.png', '24'],
#  ['/content/mchar_test_a/000037.png', '22'],
#  ['/content/mchar_test_a/000038.png', '165'],
#  ['/content/mchar_test_a/000039.png', '28'],
#  ['/content/mchar_test_a/000040.png', '1'],
#  ['/content/mchar_test_a/000041.png', '191'],
#  ['/content/mchar_test_a/000042.png', '44'],
#  ['/content/mchar_test_a/000043.png', '81'],
#  ['/content/mchar_test_a/000044.png', '67'],
#  ['/content/mchar_test_a/000045.png', '72'],
#  ['/content/mchar_test_a/000046.png', '81'],
#  ['/content/mchar_test_a/000047.png', '29'],
#  ['/content/mchar_test_a/000048.png', '56'],
#  ['/content/mchar_test_a/000049.png', '9'],
#  ['/content/mchar_test_a/000050.png', '22'],
#  ['/content/mchar_test_a/000051.png', '247'],
#  ['/content/mchar_test_a/000052.png', '24'],
#  ['/content/mchar_test_a/000053.png', '309'],
#  ['/content/mchar_test_a/000054.png', '2'],
#  ['/content/mchar_test_a/000055.png', '34'],
#  ['/content/mchar_test_a/000056.png', '36'],
#  ['/content/mchar_test_a/000057.png', '5'],
#  ['/content/mchar_test_a/000058.png', '646'],
#  ['/content/mchar_test_a/000059.png', '160'],
#  ['/content/mchar_test_a/000060.png', '17'],
#  ['/content/mchar_test_a/000061.png', '274'],
#  ['/content/mchar_test_a/000062.png', '246'],
#  ['/content/mchar_test_a/000063.png', '648'],
#  ['/content/mchar_test_a/000064.png', '273'],
#  ['/content/mchar_test_a/000065.png', '15'],
#  ['/content/mchar_test_a/000066.png', '56'],
#  ['/content/mchar_test_a/000067.png', '64'],
#  ['/content/mchar_test_a/000068.png', '552'],
#  ['/content/mchar_test_a/000069.png', '851'],
#  ['/content/mchar_test_a/000070.png', '292'],
#  ['/content/mchar_test_a/000071.png', '83'],
#  ['/content/mchar_test_a/000072.png', '28'],
#  ['/content/mchar_test_a/000073.png', '52'],
#  ['/content/mchar_test_a/000074.png', '72'],
#  ['/content/mchar_test_a/000075.png', '612'],
#  ['/content/mchar_test_a/000076.png', '41'],
#  ['/content/mchar_test_a/000077.png', '307'],
#  ['/content/mchar_test_a/000078.png', '437'],
#  ['/content/mchar_test_a/000079.png', '36'],
#  ['/content/mchar_test_a/000080.png', '5'],
#  ['/content/mchar_test_a/000081.png', '17'],
#  ['/content/mchar_test_a/000082.png', '159'],
#  ['/content/mchar_test_a/000083.png', '228'],
#  ['/content/mchar_test_a/000084.png', '47'],
#  ['/content/mchar_test_a/000085.png', '82'],
#  ['/content/mchar_test_a/000086.png', '30'],
#  ['/content/mchar_test_a/000087.png', '44'],
#  ['/content/mchar_test_a/000088.png', '124'],
#  ['/content/mchar_test_a/000089.png', '113'],
#  ['/content/mchar_test_a/000090.png', '1376'],
#  ['/content/mchar_test_a/000091.png', '428'],
#  ['/content/mchar_test_a/000092.png', '97'],
#  ['/content/mchar_test_a/000093.png', '70'],
#  ['/content/mchar_test_a/000094.png', '4'],
#  ['/content/mchar_test_a/000095.png', '37'],
#  ['/content/mchar_test_a/000096.png', '88'],
#  ['/content/mchar_test_a/000097.png', '62'],
#  ['/content/mchar_test_a/000098.png', '204'],
#  ['/content/mchar_test_a/000099.png', '805'],
#  ['/content/mchar_test_a/000100.png', '19'],
#  ['/content/mchar_test_a/000101.png', '375'],
#  ['/content/mchar_test_a/000102.png', '2'],
#  ['/content/mchar_test_a/000103.png', '71'],
#  ['/content/mchar_test_a/000104.png', '95'],
#  ['/content/mchar_test_a/000105.png', '368'],
#  ['/content/mchar_test_a/000106.png', '31'],
#  ['/content/mchar_test_a/000107.png', '49'],
#  ['/content/mchar_test_a/000108.png', '65'],
#  ['/content/mchar_test_a/000109.png', '99'],
#  ['/content/mchar_test_a/000110.png', '1584'],
#  ['/content/mchar_test_a/000111.png', '23'],
#  ['/content/mchar_test_a/000112.png', '328'],
#  ['/content/mchar_test_a/000113.png', '539'],
#  ['/content/mchar_test_a/000114.png', '418'],
#  ['/content/mchar_test_a/000115.png', '181'],
#  ['/content/mchar_test_a/000116.png', '229'],
#  ['/content/mchar_test_a/000117.png', '4'],
#  ['/content/mchar_test_a/000118.png', '46'],
#  ['/content/mchar_test_a/000119.png', '515'],
#  ['/content/mchar_test_a/000120.png', '64'],
#  ['/content/mchar_test_a/000121.png', '55'],
#  ['/content/mchar_test_a/000122.png', '752'],
#  ['/content/mchar_test_a/000123.png', '652'],
#  ['/content/mchar_test_a/000124.png', '167'],
#  ['/content/mchar_test_a/000125.png', '193'],
#  ['/content/mchar_test_a/000126.png', '191'],
#  ['/content/mchar_test_a/000127.png', '161'],
#  ['/content/mchar_test_a/000128.png', '52'],
#  ['/content/mchar_test_a/000129.png', '93'],
#  ['/content/mchar_test_a/000130.png', '219'],
#  ['/content/mchar_test_a/000131.png', '12'],
#  ['/content/mchar_test_a/000132.png', '2'],
#  ['/content/mchar_test_a/000133.png', '99'],
#  ['/content/mchar_test_a/000134.png', '356'],
#  ['/content/mchar_test_a/000135.png', '90'],
#  ['/content/mchar_test_a/000136.png', '197'],
#  ['/content/mchar_test_a/000137.png', '209'],
#  ['/content/mchar_test_a/000138.png', '183'],
#  ['/content/mchar_test_a/000139.png', '127'],
#  ['/content/mchar_test_a/000140.png', '307'],
#  ['/content/mchar_test_a/000141.png', '788'],
#  ['/content/mchar_test_a/000142.png', '389'],
#  ['/content/mchar_test_a/000143.png', '690'],
#  ['/content/mchar_test_a/000144.png', '154'],
#  ['/content/mchar_test_a/000145.png', '21'],
#  ['/content/mchar_test_a/000146.png', '22'],
#  ['/content/mchar_test_a/000147.png', '256'],
#  ['/content/mchar_test_a/000148.png', '161'],
#  ['/content/mchar_test_a/000149.png', '146'],
#  ['/content/mchar_test_a/000150.png', '1315'],
#  ['/content/mchar_test_a/000151.png', '347'],
#  ['/content/mchar_test_a/000152.png', '139'],
#  ['/content/mchar_test_a/000153.png', '220'],
#  ['/content/mchar_test_a/000154.png', '487'],
#  ['/content/mchar_test_a/000155.png', '322'],
#  ['/content/mchar_test_a/000156.png', '46'],
#  ['/content/mchar_test_a/000157.png', '527'],
#  ['/content/mchar_test_a/000158.png', '12'],
#  ['/content/mchar_test_a/000159.png', '10'],
#  ['/content/mchar_test_a/000160.png', '237'],
#  ['/content/mchar_test_a/000161.png', '460'],
#  ['/content/mchar_test_a/000162.png', '12'],
#  ['/content/mchar_test_a/000163.png', '38'],
#  ['/content/mchar_test_a/000164.png', '311'],
#  ['/content/mchar_test_a/000165.png', '156'],
#  ['/content/mchar_test_a/000166.png', '68'],
#  ['/content/mchar_test_a/000167.png', '92'],
#  ['/content/mchar_test_a/000168.png', '530'],
#  ['/content/mchar_test_a/000169.png', '75'],
#  ['/content/mchar_test_a/000170.png', '345'],
#  ['/content/mchar_test_a/000171.png', '79'],
#  ['/content/mchar_test_a/000172.png', '52'],
#  ['/content/mchar_test_a/000173.png', '251'],
#  ['/content/mchar_test_a/000174.png', '132'],
#  ['/content/mchar_test_a/000175.png', '379'],
#  ['/content/mchar_test_a/000176.png', '525'],
#  ['/content/mchar_test_a/000177.png', '25'],
#  ['/content/mchar_test_a/000178.png', '58'],
#  ['/content/mchar_test_a/000179.png', '27'],
#  ['/content/mchar_test_a/000180.png', '133'],
#  ['/content/mchar_test_a/000181.png', '56'],
#  ['/content/mchar_test_a/000182.png', '319'],
#  ['/content/mchar_test_a/000183.png', '182'],
#  ['/content/mchar_test_a/000184.png', '120'],
#  ['/content/mchar_test_a/000185.png', '80'],
#  ['/content/mchar_test_a/000186.png', '30'],
#  ['/content/mchar_test_a/000187.png', '16'],
#  ['/content/mchar_test_a/000188.png', '220'],
#  ['/content/mchar_test_a/000189.png', '280'],
#  ['/content/mchar_test_a/000190.png', '162'],
#  ['/content/mchar_test_a/000191.png', '2369'],
#  ['/content/mchar_test_a/000192.png', '470'],
#  ['/content/mchar_test_a/000193.png', '59'],
#  ['/content/mchar_test_a/000194.png', '964'],
#  ['/content/mchar_test_a/000195.png', '213'],
#  ['/content/mchar_test_a/000196.png', '157'],
#  ['/content/mchar_test_a/000197.png', '209'],
#  ['/content/mchar_test_a/000198.png', '63'],
#  ['/content/mchar_test_a/000199.png', '3'],
#  ['/content/mchar_test_a/000200.png', '85'],
#  ['/content/mchar_test_a/000201.png', '515'],
#  ['/content/mchar_test_a/000202.png', '6'],
#  ['/content/mchar_test_a/000203.png', '440'],
#  ['/content/mchar_test_a/000204.png', '12'],
#  ['/content/mchar_test_a/000205.png', '220'],
#  ['/content/mchar_test_a/000206.png', '1000'],
#  ['/content/mchar_test_a/000207.png', '1272'],
#  ['/content/mchar_test_a/000208.png', '61'],
#  ['/content/mchar_test_a/000209.png', '5520'],
#  ['/content/mchar_test_a/000210.png', '19'],
#  ['/content/mchar_test_a/000211.png', '2'],
#  ['/content/mchar_test_a/000212.png', '154'],
#  ['/content/mchar_test_a/000213.png', '183'],
#  ['/content/mchar_test_a/000214.png', '619'],
#  ['/content/mchar_test_a/000215.png', '116'],
#  ['/content/mchar_test_a/000216.png', '946'],
#  ['/content/mchar_test_a/000217.png', '101'],
#  ['/content/mchar_test_a/000218.png', '1032'],
#  ['/content/mchar_test_a/000219.png', '180'],
#  ['/content/mchar_test_a/000220.png', '4'],
#  ['/content/mchar_test_a/000221.png', '97'],
#  ['/content/mchar_test_a/000222.png', '33'],
#  ['/content/mchar_test_a/000223.png', '237'],
#  ['/content/mchar_test_a/000224.png', '1218'],
#  ['/content/mchar_test_a/000225.png', '110'],
#  ['/content/mchar_test_a/000226.png', '300'],
#  ['/content/mchar_test_a/000227.png', '283'],
#  ['/content/mchar_test_a/000228.png', '143'],
#  ['/content/mchar_test_a/000229.png', '8'],
#  ['/content/mchar_test_a/000230.png', '140'],
#  ['/content/mchar_test_a/000231.png', '561'],
#  ['/content/mchar_test_a/000232.png', '35'],
#  ['/content/mchar_test_a/000233.png', '245'],
#  ['/content/mchar_test_a/000234.png', '3161'],
#  ['/content/mchar_test_a/000235.png', '185'],
#  ['/content/mchar_test_a/000236.png', '217'],
#  ['/content/mchar_test_a/000237.png', '223'],
#  ['/content/mchar_test_a/000238.png', '234'],
#  ['/content/mchar_test_a/000239.png', '28'],
#  ['/content/mchar_test_a/000240.png', '189'],
#  ['/content/mchar_test_a/000241.png', '37'],
#  ['/content/mchar_test_a/000242.png', '4765'],
#  ['/content/mchar_test_a/000243.png', '61'],
#  ['/content/mchar_test_a/000244.png', '984'],
#  ['/content/mchar_test_a/000245.png', '15'],
#  ['/content/mchar_test_a/000246.png', '21'],
#  ['/content/mchar_test_a/000247.png', '515'],
#  ['/content/mchar_test_a/000248.png', '28'],
#  ['/content/mchar_test_a/000249.png', '16'],
#  ['/content/mchar_test_a/000250.png', '87'],
#  ['/content/mchar_test_a/000251.png', '345'],
#  ['/content/mchar_test_a/000252.png', '150'],
#  ['/content/mchar_test_a/000253.png', '225'],
#  ['/content/mchar_test_a/000254.png', '330'],
#  ['/content/mchar_test_a/000255.png', '22'],
#  ['/content/mchar_test_a/000256.png', '94'],
#  ['/content/mchar_test_a/000257.png', '287'],
#  ['/content/mchar_test_a/000258.png', '70'],
#  ['/content/mchar_test_a/000259.png', '206'],
#  ['/content/mchar_test_a/000260.png', '217'],
#  ['/content/mchar_test_a/000261.png', '18'],
#  ['/content/mchar_test_a/000262.png', '16'],
#  ['/content/mchar_test_a/000263.png', '4'],
#  ['/content/mchar_test_a/000264.png', '5'],
#  ['/content/mchar_test_a/000265.png', '261'],
#  ['/content/mchar_test_a/000266.png', '10'],
#  ['/content/mchar_test_a/000267.png', '28'],
#  ['/content/mchar_test_a/000268.png', '555'],
#  ['/content/mchar_test_a/000269.png', '95'],
#  ['/content/mchar_test_a/000270.png', '663'],
#  ['/content/mchar_test_a/000271.png', '252'],
#  ['/content/mchar_test_a/000272.png', '163'],
#  ['/content/mchar_test_a/000273.png', '1700'],
#  ['/content/mchar_test_a/000274.png', '418'],
#  ['/content/mchar_test_a/000275.png', '65'],
#  ['/content/mchar_test_a/000276.png', '696'],
#  ['/content/mchar_test_a/000277.png', '2008'],
#  ['/content/mchar_test_a/000278.png', '23'],
#  ['/content/mchar_test_a/000279.png', '346'],
#  ['/content/mchar_test_a/000280.png', '30'],
#  ['/content/mchar_test_a/000281.png', '514'],
#  ['/content/mchar_test_a/000282.png', '54'],
#  ['/content/mchar_test_a/000283.png', '125'],
#  ['/content/mchar_test_a/000284.png', '321'],
#  ['/content/mchar_test_a/000285.png', '152'],
#  ['/content/mchar_test_a/000286.png', '1955'],
#  ['/content/mchar_test_a/000287.png', '4'],
#  ['/content/mchar_test_a/000288.png', '547'],
#  ['/content/mchar_test_a/000289.png', '154'],
#  ['/content/mchar_test_a/000290.png', '353'],
#  ['/content/mchar_test_a/000291.png', '271'],
#  ['/content/mchar_test_a/000292.png', '883'],
#  ['/content/mchar_test_a/000293.png', '194'],
#  ['/content/mchar_test_a/000294.png', '2'],
#  ['/content/mchar_test_a/000295.png', '59'],
#  ['/content/mchar_test_a/000296.png', '267'],
#  ['/content/mchar_test_a/000297.png', '2350'],
#  ['/content/mchar_test_a/000298.png', '60'],
#  ['/content/mchar_test_a/000299.png', '47'],
#  ['/content/mchar_test_a/000300.png', '55'],
#  ['/content/mchar_test_a/000301.png', '913'],
#  ['/content/mchar_test_a/000302.png', '867'],
#  ['/content/mchar_test_a/000303.png', '1336'],
#  ['/content/mchar_test_a/000304.png', '150'],
#  ['/content/mchar_test_a/000305.png', '7'],
#  ['/content/mchar_test_a/000306.png', '18'],
#  ['/content/mchar_test_a/000307.png', '107'],
#  ['/content/mchar_test_a/000308.png', '34'],
#  ['/content/mchar_test_a/000309.png', '110'],
#  ['/content/mchar_test_a/000310.png', '533'],
#  ['/content/mchar_test_a/000311.png', '110'],
#  ['/content/mchar_test_a/000312.png', '2'],
#  ['/content/mchar_test_a/000313.png', '194'],
#  ['/content/mchar_test_a/000314.png', '75'],
#  ['/content/mchar_test_a/000315.png', '26'],
#  ['/content/mchar_test_a/000316.png', '27'],
#  ['/content/mchar_test_a/000317.png', '23'],
#  ['/content/mchar_test_a/000318.png', '5'],
#  ['/content/mchar_test_a/000319.png', '443'],
#  ['/content/mchar_test_a/000320.png', '291'],
#  ['/content/mchar_test_a/000321.png', '66'],
#  ['/content/mchar_test_a/000322.png', '333'],
#  ['/content/mchar_test_a/000323.png', '323'],
#  ['/content/mchar_test_a/000324.png', '22'],
#  ['/content/mchar_test_a/000325.png', '106'],
#  ['/content/mchar_test_a/000326.png', '20'],
#  ['/content/mchar_test_a/000327.png', '99'],
#  ['/content/mchar_test_a/000328.png', '396'],
#  ['/content/mchar_test_a/000329.png', '1473'],
#  ['/content/mchar_test_a/000330.png', '409'],
#  ['/content/mchar_test_a/000331.png', '180'],
#  ['/content/mchar_test_a/000332.png', '424'],
#  ['/content/mchar_test_a/000333.png', '83'],
#  ['/content/mchar_test_a/000334.png', '104'],
#  ['/content/mchar_test_a/000335.png', '692'],
#  ['/content/mchar_test_a/000336.png', '21'],
#  ['/content/mchar_test_a/000337.png', '7'],
#  ['/content/mchar_test_a/000338.png', '290'],
#  ['/content/mchar_test_a/000339.png', '125'],
#  ['/content/mchar_test_a/000340.png', '634'],
#  ['/content/mchar_test_a/000341.png', '75'],
#  ['/content/mchar_test_a/000342.png', '375'],
#  ['/content/mchar_test_a/000343.png', '709'],
#  ['/content/mchar_test_a/000344.png', '43'],
#  ['/content/mchar_test_a/000345.png', '15'],
#  ['/content/mchar_test_a/000346.png', '19'],
#  ['/content/mchar_test_a/000347.png', '180'],
#  ['/content/mchar_test_a/000348.png', '588'],
#  ['/content/mchar_test_a/000349.png', '160'],
#  ['/content/mchar_test_a/000350.png', '1000'],
#  ['/content/mchar_test_a/000351.png', '215'],
#  ['/content/mchar_test_a/000352.png', '44'],
#  ['/content/mchar_test_a/000353.png', '216'],
#  ['/content/mchar_test_a/000354.png', '9'],
#  ['/content/mchar_test_a/000355.png', '11'],
#  ['/content/mchar_test_a/000356.png', '600'],
#  ['/content/mchar_test_a/000357.png', '236'],
#  ['/content/mchar_test_a/000358.png', '74'],
#  ['/content/mchar_test_a/000359.png', '109'],
#  ['/content/mchar_test_a/000360.png', '136'],
#  ['/content/mchar_test_a/000361.png', '287'],
#  ['/content/mchar_test_a/000362.png', '70'],
#  ['/content/mchar_test_a/000363.png', '100'],
#  ['/content/mchar_test_a/000364.png', '20'],
#  ['/content/mchar_test_a/000365.png', '116'],
#  ['/content/mchar_test_a/000366.png', '444'],
#  ['/content/mchar_test_a/000367.png', '2675'],
#  ['/content/mchar_test_a/000368.png', '484'],
#  ['/content/mchar_test_a/000369.png', '281'],
#  ['/content/mchar_test_a/000370.png', '5000'],
#  ['/content/mchar_test_a/000371.png', '295'],
#  ['/content/mchar_test_a/000372.png', '28'],
#  ['/content/mchar_test_a/000373.png', '152'],
#  ['/content/mchar_test_a/000374.png', '35'],
#  ['/content/mchar_test_a/000375.png', '2446'],
#  ['/content/mchar_test_a/000376.png', '165'],
#  ['/content/mchar_test_a/000377.png', '61'],
#  ['/content/mchar_test_a/000378.png', '75'],
#  ['/content/mchar_test_a/000379.png', '44'],
#  ['/content/mchar_test_a/000380.png', '624'],
#  ['/content/mchar_test_a/000381.png', '117'],
#  ['/content/mchar_test_a/000382.png', '95'],
#  ['/content/mchar_test_a/000383.png', '313'],
#  ['/content/mchar_test_a/000384.png', '287'],
#  ['/content/mchar_test_a/000385.png', '467'],
#  ['/content/mchar_test_a/000386.png', '449'],
#  ['/content/mchar_test_a/000387.png', '63'],
#  ['/content/mchar_test_a/000388.png', '30'],
#  ['/content/mchar_test_a/000389.png', '31'],
#  ['/content/mchar_test_a/000390.png', '33'],
#  ['/content/mchar_test_a/000391.png', '18'],
#  ['/content/mchar_test_a/000392.png', '12'],
#  ['/content/mchar_test_a/000393.png', '67'],
#  ['/content/mchar_test_a/000394.png', '160'],
#  ['/content/mchar_test_a/000395.png', '14'],
#  ['/content/mchar_test_a/000396.png', '606'],
#  ['/content/mchar_test_a/000397.png', '904'],
#  ['/content/mchar_test_a/000398.png', '433'],
#  ['/content/mchar_test_a/000399.png', '42'],
#  ['/content/mchar_test_a/000400.png', '445'],
#  ['/content/mchar_test_a/000401.png', '341'],
#  ['/content/mchar_test_a/000402.png', '154'],
#  ['/content/mchar_test_a/000403.png', '129'],
#  ['/content/mchar_test_a/000404.png', '2020'],
#  ['/content/mchar_test_a/000405.png', '1710'],
#  ['/content/mchar_test_a/000406.png', '91'],
#  ['/content/mchar_test_a/000407.png', '22'],
#  ['/content/mchar_test_a/000408.png', '8'],
#  ['/content/mchar_test_a/000409.png', '1452'],
#  ['/content/mchar_test_a/000410.png', '1362'],
#  ['/content/mchar_test_a/000411.png', '736'],
#  ['/content/mchar_test_a/000412.png', '63'],
#  ['/content/mchar_test_a/000413.png', '119'],
#  ['/content/mchar_test_a/000414.png', '250'],
#  ['/content/mchar_test_a/000415.png', '20'],
#  ['/content/mchar_test_a/000416.png', '368'],
#  ['/content/mchar_test_a/000417.png', '12'],
#  ['/content/mchar_test_a/000418.png', '32'],
#  ['/content/mchar_test_a/000419.png', '207'],
#  ['/content/mchar_test_a/000420.png', '174'],
#  ['/content/mchar_test_a/000421.png', '155'],
#  ['/content/mchar_test_a/000422.png', '59'],
#  ['/content/mchar_test_a/000423.png', '1783'],
#  ['/content/mchar_test_a/000424.png', '12'],
#  ['/content/mchar_test_a/000425.png', '510'],
#  ['/content/mchar_test_a/000426.png', '64'],
#  ['/content/mchar_test_a/000427.png', '1288'],
#  ['/content/mchar_test_a/000428.png', '76'],
#  ['/content/mchar_test_a/000429.png', '858'],
#  ['/content/mchar_test_a/000430.png', '71'],
#  ['/content/mchar_test_a/000431.png', '293'],
#  ['/content/mchar_test_a/000432.png', '1280'],
#  ['/content/mchar_test_a/000433.png', '76'],
#  ['/content/mchar_test_a/000434.png', '28'],
#  ['/content/mchar_test_a/000435.png', '23'],
#  ['/content/mchar_test_a/000436.png', '372'],
#  ['/content/mchar_test_a/000437.png', '16'],
#  ['/content/mchar_test_a/000438.png', '764'],
#  ['/content/mchar_test_a/000439.png', '123'],
#  ['/content/mchar_test_a/000440.png', '15'],
#  ['/content/mchar_test_a/000441.png', '223'],
#  ['/content/mchar_test_a/000442.png', '7'],
#  ['/content/mchar_test_a/000443.png', '104'],
#  ['/content/mchar_test_a/000444.png', '417'],
#  ['/content/mchar_test_a/000445.png', '46'],
#  ['/content/mchar_test_a/000446.png', '169'],
#  ['/content/mchar_test_a/000447.png', '649'],
#  ['/content/mchar_test_a/000448.png', '81'],
#  ['/content/mchar_test_a/000449.png', '204'],
#  ['/content/mchar_test_a/000450.png', '86'],
#  ['/content/mchar_test_a/000451.png', '85'],
#  ['/content/mchar_test_a/000452.png', '25'],
#  ['/content/mchar_test_a/000453.png', '244'],
#  ['/content/mchar_test_a/000454.png', '1051'],
#  ['/content/mchar_test_a/000455.png', '3225'],
#  ['/content/mchar_test_a/000456.png', '929'],
#  ['/content/mchar_test_a/000457.png', '22'],
#  ['/content/mchar_test_a/000458.png', '223'],
#  ['/content/mchar_test_a/000459.png', '1225'],
#  ['/content/mchar_test_a/000460.png', '166'],
#  ['/content/mchar_test_a/000461.png', '100'],
#  ['/content/mchar_test_a/000462.png', '7'],
#  ['/content/mchar_test_a/000463.png', '36'],
#  ['/content/mchar_test_a/000464.png', '1048'],
#  ['/content/mchar_test_a/000465.png', '92'],
#  ['/content/mchar_test_a/000466.png', '67'],
#  ['/content/mchar_test_a/000467.png', '382'],
#  ['/content/mchar_test_a/000468.png', '1980'],
#  ['/content/mchar_test_a/000469.png', '215'],
#  ['/content/mchar_test_a/000470.png', '104'],
#  ['/content/mchar_test_a/000471.png', '171'],
#  ['/content/mchar_test_a/000472.png', '29'],
#  ['/content/mchar_test_a/000473.png', '1500'],
#  ['/content/mchar_test_a/000474.png', '20'],
#  ['/content/mchar_test_a/000475.png', '908'],
#  ['/content/mchar_test_a/000476.png', '586'],
#  ['/content/mchar_test_a/000477.png', '18'],
#  ['/content/mchar_test_a/000478.png', '25'],
#  ['/content/mchar_test_a/000479.png', '2635'],
#  ['/content/mchar_test_a/000480.png', '201'],
#  ['/content/mchar_test_a/000481.png', '145'],
#  ['/content/mchar_test_a/000482.png', '10'],
#  ['/content/mchar_test_a/000483.png', '283'],
#  ['/content/mchar_test_a/000484.png', '86'],
#  ['/content/mchar_test_a/000485.png', '39'],
#  ['/content/mchar_test_a/000486.png', '1051'],
#  ['/content/mchar_test_a/000487.png', '542'],
#  ['/content/mchar_test_a/000488.png', '293'],
#  ['/content/mchar_test_a/000489.png', '94'],
#  ['/content/mchar_test_a/000490.png', '99'],
#  ['/content/mchar_test_a/000491.png', '274'],
#  ['/content/mchar_test_a/000492.png', '225'],
#  ['/content/mchar_test_a/000493.png', '106'],
#  ['/content/mchar_test_a/000494.png', '22'],
#  ['/content/mchar_test_a/000495.png', '105'],
#  ['/content/mchar_test_a/000496.png', '77'],
#  ['/content/mchar_test_a/000497.png', '75'],
#  ['/content/mchar_test_a/000498.png', '50'],
#  ['/content/mchar_test_a/000499.png', '1252'],
#  ['/content/mchar_test_a/000500.png', '65'],
#  ['/content/mchar_test_a/000501.png', '238'],
#  ['/content/mchar_test_a/000502.png', '758'],
#  ['/content/mchar_test_a/000503.png', '48'],
#  ['/content/mchar_test_a/000504.png', '107'],
#  ['/content/mchar_test_a/000505.png', '387'],
#  ['/content/mchar_test_a/000506.png', '388'],
#  ['/content/mchar_test_a/000507.png', '31'],
#  ['/content/mchar_test_a/000508.png', '62'],
#  ['/content/mchar_test_a/000509.png', '110'],
#  ['/content/mchar_test_a/000510.png', '12'],
#  ['/content/mchar_test_a/000511.png', '128'],
#  ['/content/mchar_test_a/000512.png', '9730'],
#  ['/content/mchar_test_a/000513.png', '1174'],
#  ['/content/mchar_test_a/000514.png', '65'],
#  ['/content/mchar_test_a/000515.png', '300'],
#  ['/content/mchar_test_a/000516.png', '181'],
#  ['/content/mchar_test_a/000517.png', '45'],
#  ['/content/mchar_test_a/000518.png', '21'],
#  ['/content/mchar_test_a/000519.png', '447'],
#  ['/content/mchar_test_a/000520.png', '10'],
#  ['/content/mchar_test_a/000521.png', '62'],
#  ['/content/mchar_test_a/000522.png', '501'],
#  ['/content/mchar_test_a/000523.png', '111'],
#  ['/content/mchar_test_a/000524.png', '211'],
#  ['/content/mchar_test_a/000525.png', '66'],
#  ['/content/mchar_test_a/000526.png', '309'],
#  ['/content/mchar_test_a/000527.png', '99'],
#  ['/content/mchar_test_a/000528.png', '2380'],
#  ['/content/mchar_test_a/000529.png', '317'],
#  ['/content/mchar_test_a/000530.png', '4464'],
#  ['/content/mchar_test_a/000531.png', '252'],
#  ['/content/mchar_test_a/000532.png', '298'],
#  ['/content/mchar_test_a/000533.png', '25'],
#  ['/content/mchar_test_a/000534.png', '90'],
#  ['/content/mchar_test_a/000535.png', '427'],
#  ['/content/mchar_test_a/000536.png', '302'],
#  ['/content/mchar_test_a/000537.png', '49'],
#  ['/content/mchar_test_a/000538.png', '3'],
#  ['/content/mchar_test_a/000539.png', '174'],
#  ['/content/mchar_test_a/000540.png', '173'],
#  ['/content/mchar_test_a/000541.png', '12'],
#  ['/content/mchar_test_a/000542.png', '438'],
#  ['/content/mchar_test_a/000543.png', '565'],
#  ['/content/mchar_test_a/000544.png', '468'],
#  ['/content/mchar_test_a/000545.png', '57'],
#  ['/content/mchar_test_a/000546.png', '1333'],
#  ['/content/mchar_test_a/000547.png', '77'],
#  ['/content/mchar_test_a/000548.png', '21'],
#  ['/content/mchar_test_a/000549.png', '280'],
#  ['/content/mchar_test_a/000550.png', '336'],
#  ['/content/mchar_test_a/000551.png', '130'],
#  ['/content/mchar_test_a/000552.png', '8'],
#  ['/content/mchar_test_a/000553.png', '174'],
#  ['/content/mchar_test_a/000554.png', '194'],
#  ['/content/mchar_test_a/000555.png', '1'],
#  ['/content/mchar_test_a/000556.png', '128'],
#  ['/content/mchar_test_a/000557.png', '38'],
#  ['/content/mchar_test_a/000558.png', '597'],
#  ['/content/mchar_test_a/000559.png', '518'],
#  ['/content/mchar_test_a/000560.png', '59'],
#  ['/content/mchar_test_a/000561.png', '15'],
#  ['/content/mchar_test_a/000562.png', '133'],
#  ['/content/mchar_test_a/000563.png', '922'],
#  ['/content/mchar_test_a/000564.png', '20'],
#  ['/content/mchar_test_a/000565.png', '208'],
#  ['/content/mchar_test_a/000566.png', '41'],
#  ['/content/mchar_test_a/000567.png', '21'],
#  ['/content/mchar_test_a/000568.png', '203'],
#  ['/content/mchar_test_a/000569.png', '58'],
#  ['/content/mchar_test_a/000570.png', '276'],
#  ['/content/mchar_test_a/000571.png', '129'],
#  ['/content/mchar_test_a/000572.png', '69'],
#  ['/content/mchar_test_a/000573.png', '90'],
#  ['/content/mchar_test_a/000574.png', '158'],
#  ['/content/mchar_test_a/000575.png', '324'],
#  ['/content/mchar_test_a/000576.png', '630'],
#  ['/content/mchar_test_a/000577.png', '212'],
#  ['/content/mchar_test_a/000578.png', '35'],
#  ['/content/mchar_test_a/000579.png', '273'],
#  ['/content/mchar_test_a/000580.png', '2'],
#  ['/content/mchar_test_a/000581.png', '106'],
#  ['/content/mchar_test_a/000582.png', '274'],
#  ['/content/mchar_test_a/000583.png', '68'],
#  ['/content/mchar_test_a/000584.png', '631'],
#  ['/content/mchar_test_a/000585.png', '266'],
#  ['/content/mchar_test_a/000586.png', '151'],
#  ['/content/mchar_test_a/000587.png', '227'],
#  ['/content/mchar_test_a/000588.png', '699'],
#  ['/content/mchar_test_a/000589.png', '55'],
#  ['/content/mchar_test_a/000590.png', '131'],
#  ['/content/mchar_test_a/000591.png', '118'],
#  ['/content/mchar_test_a/000592.png', '1'],
#  ['/content/mchar_test_a/000593.png', '25'],
#  ['/content/mchar_test_a/000594.png', '38'],
#  ['/content/mchar_test_a/000595.png', '24'],
#  ['/content/mchar_test_a/000596.png', '3101'],
#  ['/content/mchar_test_a/000597.png', '321'],
#  ['/content/mchar_test_a/000598.png', '1690'],
#  ['/content/mchar_test_a/000599.png', '3'],
#  ['/content/mchar_test_a/000600.png', '164'],
#  ['/content/mchar_test_a/000601.png', '209'],
#  ['/content/mchar_test_a/000602.png', '287'],
#  ['/content/mchar_test_a/000603.png', '389'],
#  ['/content/mchar_test_a/000604.png', '234'],
#  ['/content/mchar_test_a/000605.png', '194'],
#  ['/content/mchar_test_a/000606.png', '477'],
#  ['/content/mchar_test_a/000607.png', '12'],
#  ['/content/mchar_test_a/000608.png', '225'],
#  ['/content/mchar_test_a/000609.png', '285'],
#  ['/content/mchar_test_a/000610.png', '47'],
#  ['/content/mchar_test_a/000611.png', '251'],
#  ['/content/mchar_test_a/000612.png', '151'],
#  ['/content/mchar_test_a/000613.png', '29'],
#  ['/content/mchar_test_a/000614.png', '117'],
#  ['/content/mchar_test_a/000615.png', '28'],
#  ['/content/mchar_test_a/000616.png', '147'],
#  ['/content/mchar_test_a/000617.png', '2922'],
#  ['/content/mchar_test_a/000618.png', '46'],
#  ['/content/mchar_test_a/000619.png', '21'],
#  ['/content/mchar_test_a/000620.png', '990'],
#  ['/content/mchar_test_a/000621.png', '9'],
#  ['/content/mchar_test_a/000622.png', '24'],
#  ['/content/mchar_test_a/000623.png', '814'],
#  ['/content/mchar_test_a/000624.png', '75'],
#  ['/content/mchar_test_a/000625.png', '15'],
#  ['/content/mchar_test_a/000626.png', '2'],
#  ['/content/mchar_test_a/000627.png', '1546'],
#  ['/content/mchar_test_a/000628.png', '129'],
#  ['/content/mchar_test_a/000629.png', '182'],
#  ['/content/mchar_test_a/000630.png', '217'],
#  ['/content/mchar_test_a/000631.png', '36'],
#  ['/content/mchar_test_a/000632.png', '225'],
#  ['/content/mchar_test_a/000633.png', '192'],
#  ['/content/mchar_test_a/000634.png', '188'],
#  ['/content/mchar_test_a/000635.png', '298'],
#  ['/content/mchar_test_a/000636.png', '15'],
#  ['/content/mchar_test_a/000637.png', '61'],
#  ['/content/mchar_test_a/000638.png', '155'],
#  ['/content/mchar_test_a/000639.png', '873'],
#  ['/content/mchar_test_a/000640.png', '455'],
#  ['/content/mchar_test_a/000641.png', '97'],
#  ['/content/mchar_test_a/000642.png', '495'],
#  ['/content/mchar_test_a/000643.png', '280'],
#  ['/content/mchar_test_a/000644.png', '564'],
#  ['/content/mchar_test_a/000645.png', '218'],
#  ['/content/mchar_test_a/000646.png', '78'],
#  ['/content/mchar_test_a/000647.png', '500'],
#  ['/content/mchar_test_a/000648.png', '320'],
#  ['/content/mchar_test_a/000649.png', '280'],
#  ['/content/mchar_test_a/000650.png', '576'],
#  ['/content/mchar_test_a/000651.png', '382'],
#  ['/content/mchar_test_a/000652.png', '1783'],
#  ['/content/mchar_test_a/000653.png', '1455'],
#  ['/content/mchar_test_a/000654.png', '110'],
#  ['/content/mchar_test_a/000655.png', '220'],
#  ['/content/mchar_test_a/000656.png', '22'],
#  ['/content/mchar_test_a/000657.png', '140'],
#  ['/content/mchar_test_a/000658.png', '25'],
#  ['/content/mchar_test_a/000659.png', '337'],
#  ['/content/mchar_test_a/000660.png', '419'],
#  ['/content/mchar_test_a/000661.png', '111'],
#  ['/content/mchar_test_a/000662.png', '265'],
#  ['/content/mchar_test_a/000663.png', '2395'],
#  ['/content/mchar_test_a/000664.png', '454'],
#  ['/content/mchar_test_a/000665.png', '134'],
#  ['/content/mchar_test_a/000666.png', '345'],
#  ['/content/mchar_test_a/000667.png', '200'],
#  ['/content/mchar_test_a/000668.png', '363'],
#  ['/content/mchar_test_a/000669.png', '272'],
#  ['/content/mchar_test_a/000670.png', '2133'],
#  ['/content/mchar_test_a/000671.png', '1433'],
#  ['/content/mchar_test_a/000672.png', '293'],
#  ['/content/mchar_test_a/000673.png', '3040'],
#  ['/content/mchar_test_a/000674.png', '1547'],
#  ['/content/mchar_test_a/000675.png', '116'],
#  ['/content/mchar_test_a/000676.png', '8'],
#  ['/content/mchar_test_a/000677.png', '29'],
#  ['/content/mchar_test_a/000678.png', '64'],
#  ['/content/mchar_test_a/000679.png', '3166'],
#  ['/content/mchar_test_a/000680.png', '143'],
#  ['/content/mchar_test_a/000681.png', '104'],
#  ['/content/mchar_test_a/000682.png', '477'],
#  ['/content/mchar_test_a/000683.png', '2435'],
#  ['/content/mchar_test_a/000684.png', '20'],
#  ['/content/mchar_test_a/000685.png', '24'],
#  ['/content/mchar_test_a/000686.png', '21'],
#  ['/content/mchar_test_a/000687.png', '34'],
#  ['/content/mchar_test_a/000688.png', '408'],
#  ['/content/mchar_test_a/000689.png', '397'],
#  ['/content/mchar_test_a/000690.png', '48'],
#  ['/content/mchar_test_a/000691.png', '93'],
#  ['/content/mchar_test_a/000692.png', '55'],
#  ['/content/mchar_test_a/000693.png', '19'],
#  ['/content/mchar_test_a/000694.png', '89'],
#  ['/content/mchar_test_a/000695.png', '147'],
#  ['/content/mchar_test_a/000696.png', '43'],
#  ['/content/mchar_test_a/000697.png', '293'],
#  ['/content/mchar_test_a/000698.png', '252'],
#  ['/content/mchar_test_a/000699.png', '124'],
#  ['/content/mchar_test_a/000700.png', '660'],
#  ['/content/mchar_test_a/000701.png', '223'],
#  ['/content/mchar_test_a/000702.png', '7'],
#  ['/content/mchar_test_a/000703.png', '322'],
#  ['/content/mchar_test_a/000704.png', '260'],
#  ['/content/mchar_test_a/000705.png', '132'],
#  ['/content/mchar_test_a/000706.png', '734'],
#  ['/content/mchar_test_a/000707.png', '56'],
#  ['/content/mchar_test_a/000708.png', '217'],
#  ['/content/mchar_test_a/000709.png', '4630'],
#  ['/content/mchar_test_a/000710.png', '392'],
#  ['/content/mchar_test_a/000711.png', '65'],
#  ['/content/mchar_test_a/000712.png', '948'],
#  ['/content/mchar_test_a/000713.png', '53'],
#  ['/content/mchar_test_a/000714.png', '221'],
#  ['/content/mchar_test_a/000715.png', '125'],
#  ['/content/mchar_test_a/000716.png', '124'],
#  ['/content/mchar_test_a/000717.png', '278'],
#  ['/content/mchar_test_a/000718.png', '44'],
#  ['/content/mchar_test_a/000719.png', '470'],
#  ['/content/mchar_test_a/000720.png', '56'],
#  ['/content/mchar_test_a/000721.png', '413'],
#  ['/content/mchar_test_a/000722.png', '22'],
#  ['/content/mchar_test_a/000723.png', '522'],
#  ['/content/mchar_test_a/000724.png', '115'],
#  ['/content/mchar_test_a/000725.png', '401'],
#  ['/content/mchar_test_a/000726.png', '160'],
#  ['/content/mchar_test_a/000727.png', '226'],
#  ['/content/mchar_test_a/000728.png', '1380'],
#  ['/content/mchar_test_a/000729.png', '19'],
#  ['/content/mchar_test_a/000730.png', '30'],
#  ['/content/mchar_test_a/000731.png', '1722'],
#  ['/content/mchar_test_a/000732.png', '72'],
#  ['/content/mchar_test_a/000733.png', '43'],
#  ['/content/mchar_test_a/000734.png', '185'],
#  ['/content/mchar_test_a/000735.png', '55'],
#  ['/content/mchar_test_a/000736.png', '585'],
#  ['/content/mchar_test_a/000737.png', '6'],
#  ['/content/mchar_test_a/000738.png', '255'],
#  ['/content/mchar_test_a/000739.png', '21'],
#  ['/content/mchar_test_a/000740.png', '129'],
#  ['/content/mchar_test_a/000741.png', '80'],
#  ['/content/mchar_test_a/000742.png', '300'],
#  ['/content/mchar_test_a/000743.png', '225'],
#  ['/content/mchar_test_a/000744.png', '126'],
#  ['/content/mchar_test_a/000745.png', '98'],
#  ['/content/mchar_test_a/000746.png', '77'],
#  ['/content/mchar_test_a/000747.png', '35'],
#  ['/content/mchar_test_a/000748.png', '1495'],
#  ['/content/mchar_test_a/000749.png', '96'],
#  ['/content/mchar_test_a/000750.png', '300'],
#  ['/content/mchar_test_a/000751.png', '1107'],
#  ['/content/mchar_test_a/000752.png', '706'],
#  ['/content/mchar_test_a/000753.png', '4'],
#  ['/content/mchar_test_a/000754.png', '87'],
#  ['/content/mchar_test_a/000755.png', '283'],
#  ['/content/mchar_test_a/000756.png', '152'],
#  ['/content/mchar_test_a/000757.png', '112'],
#  ['/content/mchar_test_a/000758.png', '99'],
#  ['/content/mchar_test_a/000759.png', '180'],
#  ['/content/mchar_test_a/000760.png', '51'],
#  ['/content/mchar_test_a/000761.png', '161'],
#  ['/content/mchar_test_a/000762.png', '900'],
#  ['/content/mchar_test_a/000763.png', '22'],
#  ['/content/mchar_test_a/000764.png', '410'],
#  ['/content/mchar_test_a/000765.png', '585'],
#  ['/content/mchar_test_a/000766.png', '336'],
#  ['/content/mchar_test_a/000767.png', '426'],
#  ['/content/mchar_test_a/000768.png', '2877'],
#  ['/content/mchar_test_a/000769.png', '74'],
#  ['/content/mchar_test_a/000770.png', '514'],
#  ['/content/mchar_test_a/000771.png', '480'],
#  ['/content/mchar_test_a/000772.png', '145'],
#  ['/content/mchar_test_a/000773.png', '343'],
#  ['/content/mchar_test_a/000774.png', '137'],
#  ['/content/mchar_test_a/000775.png', '42'],
#  ['/content/mchar_test_a/000776.png', '417'],
#  ['/content/mchar_test_a/000777.png', '71'],
#  ['/content/mchar_test_a/000778.png', '80'],
#  ['/content/mchar_test_a/000779.png', '42'],
#  ['/content/mchar_test_a/000780.png', '367'],
#  ['/content/mchar_test_a/000781.png', '106'],
#  ['/content/mchar_test_a/000782.png', '20'],
#  ['/content/mchar_test_a/000783.png', '192'],
#  ['/content/mchar_test_a/000784.png', '292'],
#  ['/content/mchar_test_a/000785.png', '8'],
#  ['/content/mchar_test_a/000786.png', '343'],
#  ['/content/mchar_test_a/000787.png', '373'],
#  ['/content/mchar_test_a/000788.png', '178'],
#  ['/content/mchar_test_a/000789.png', '355'],
#  ['/content/mchar_test_a/000790.png', '381'],
#  ['/content/mchar_test_a/000791.png', '242'],
#  ['/content/mchar_test_a/000792.png', '46'],
#  ['/content/mchar_test_a/000793.png', '293'],
#  ['/content/mchar_test_a/000794.png', '9'],
#  ['/content/mchar_test_a/000795.png', '58'],
#  ['/content/mchar_test_a/000796.png', '1'],
#  ['/content/mchar_test_a/000797.png', '15'],
#  ['/content/mchar_test_a/000798.png', '122'],
#  ['/content/mchar_test_a/000799.png', '35'],
#  ['/content/mchar_test_a/000800.png', '21'],
#  ['/content/mchar_test_a/000801.png', '434'],
#  ['/content/mchar_test_a/000802.png', '6'],
#  ['/content/mchar_test_a/000803.png', '9'],
#  ['/content/mchar_test_a/000804.png', '136'],
#  ['/content/mchar_test_a/000805.png', '25'],
#  ['/content/mchar_test_a/000806.png', '99'],
#  ['/content/mchar_test_a/000807.png', '1621'],
#  ['/content/mchar_test_a/000808.png', '21'],
#  ['/content/mchar_test_a/000809.png', '672'],
#  ['/content/mchar_test_a/000810.png', '6'],
#  ['/content/mchar_test_a/000811.png', '155'],
#  ['/content/mchar_test_a/000812.png', '95'],
#  ['/content/mchar_test_a/000813.png', '70'],
#  ['/content/mchar_test_a/000814.png', '21'],
#  ['/content/mchar_test_a/000815.png', '230'],
#  ['/content/mchar_test_a/000816.png', '285'],
#  ['/content/mchar_test_a/000817.png', '396'],
#  ['/content/mchar_test_a/000818.png', '507'],
#  ['/content/mchar_test_a/000819.png', '210'],
#  ['/content/mchar_test_a/000820.png', '1981'],
#  ['/content/mchar_test_a/000821.png', '47'],
#  ['/content/mchar_test_a/000822.png', '30'],
#  ['/content/mchar_test_a/000823.png', '5'],
#  ['/content/mchar_test_a/000824.png', '52'],
#  ['/content/mchar_test_a/000825.png', '492'],
#  ['/content/mchar_test_a/000826.png', '114'],
#  ['/content/mchar_test_a/000827.png', '424'],
#  ['/content/mchar_test_a/000828.png', '191'],
#  ['/content/mchar_test_a/000829.png', '37'],
#  ['/content/mchar_test_a/000830.png', '688'],
#  ['/content/mchar_test_a/000831.png', '26'],
#  ['/content/mchar_test_a/000832.png', '497'],
#  ['/content/mchar_test_a/000833.png', '214'],
#  ['/content/mchar_test_a/000834.png', '133'],
#  ['/content/mchar_test_a/000835.png', '163'],
#  ['/content/mchar_test_a/000836.png', '400'],
#  ['/content/mchar_test_a/000837.png', '6'],
#  ['/content/mchar_test_a/000838.png', '185'],
#  ['/content/mchar_test_a/000839.png', '22'],
#  ['/content/mchar_test_a/000840.png', '187'],
#  ['/content/mchar_test_a/000841.png', '121'],
#  ['/content/mchar_test_a/000842.png', '12'],
#  ['/content/mchar_test_a/000843.png', '8'],
#  ['/content/mchar_test_a/000844.png', '655'],
#  ['/content/mchar_test_a/000845.png', '35'],
#  ['/content/mchar_test_a/000846.png', '104'],
#  ['/content/mchar_test_a/000847.png', '8'],
#  ['/content/mchar_test_a/000848.png', '33'],
#  ['/content/mchar_test_a/000849.png', '335'],
#  ['/content/mchar_test_a/000850.png', '500'],
#  ['/content/mchar_test_a/000851.png', '136'],
#  ['/content/mchar_test_a/000852.png', '56'],
#  ['/content/mchar_test_a/000853.png', '108'],
#  ['/content/mchar_test_a/000854.png', '210'],
#  ['/content/mchar_test_a/000855.png', '80'],
#  ['/content/mchar_test_a/000856.png', '197'],
#  ['/content/mchar_test_a/000857.png', '3'],
#  ['/content/mchar_test_a/000858.png', '51'],
#  ['/content/mchar_test_a/000859.png', '251'],
#  ['/content/mchar_test_a/000860.png', '26'],
#  ['/content/mchar_test_a/000861.png', '8'],
#  ['/content/mchar_test_a/000862.png', '92'],
#  ['/content/mchar_test_a/000863.png', '33'],
#  ['/content/mchar_test_a/000864.png', '27'],
#  ['/content/mchar_test_a/000865.png', '54'],
#  ['/content/mchar_test_a/000866.png', '10'],
#  ['/content/mchar_test_a/000867.png', '993'],
#  ['/content/mchar_test_a/000868.png', '26'],
#  ['/content/mchar_test_a/000869.png', '41'],
#  ['/content/mchar_test_a/000870.png', '5'],
#  ['/content/mchar_test_a/000871.png', '22'],
#  ['/content/mchar_test_a/000872.png', '351'],
#  ['/content/mchar_test_a/000873.png', '454'],
#  ['/content/mchar_test_a/000874.png', '149'],
#  ['/content/mchar_test_a/000875.png', '363'],
#  ['/content/mchar_test_a/000876.png', '520'],
#  ['/content/mchar_test_a/000877.png', '5'],
#  ['/content/mchar_test_a/000878.png', '152'],
#  ['/content/mchar_test_a/000879.png', '270'],
#  ['/content/mchar_test_a/000880.png', '91'],
#  ['/content/mchar_test_a/000881.png', '42'],
#  ['/content/mchar_test_a/000882.png', '160'],
#  ['/content/mchar_test_a/000883.png', '1435'],
#  ['/content/mchar_test_a/000884.png', '131'],
#  ['/content/mchar_test_a/000885.png', '141'],
#  ['/content/mchar_test_a/000886.png', '318'],
#  ['/content/mchar_test_a/000887.png', '27'],
#  ['/content/mchar_test_a/000888.png', '423'],
#  ['/content/mchar_test_a/000889.png', '28'],
#  ['/content/mchar_test_a/000890.png', '5'],
#  ['/content/mchar_test_a/000891.png', '123'],
#  ['/content/mchar_test_a/000892.png', '204'],
#  ['/content/mchar_test_a/000893.png', '232'],
#  ['/content/mchar_test_a/000894.png', '853'],
#  ['/content/mchar_test_a/000895.png', '664'],
#  ['/content/mchar_test_a/000896.png', '1368'],
#  ['/content/mchar_test_a/000897.png', '32'],
#  ['/content/mchar_test_a/000898.png', '83'],
#  ['/content/mchar_test_a/000899.png', '235'],
#  ['/content/mchar_test_a/000900.png', '639'],
#  ['/content/mchar_test_a/000901.png', '568'],
#  ['/content/mchar_test_a/000902.png', '397'],
#  ['/content/mchar_test_a/000903.png', '2611'],
#  ['/content/mchar_test_a/000904.png', '140'],
#  ['/content/mchar_test_a/000905.png', '379'],
#  ['/content/mchar_test_a/000906.png', '35'],
#  ['/content/mchar_test_a/000907.png', '380'],
#  ['/content/mchar_test_a/000908.png', '78'],
#  ['/content/mchar_test_a/000909.png', '92'],
#  ['/content/mchar_test_a/000910.png', '55'],
#  ['/content/mchar_test_a/000911.png', '931'],
#  ['/content/mchar_test_a/000912.png', '178'],
#  ['/content/mchar_test_a/000913.png', '1080'],
#  ['/content/mchar_test_a/000914.png', '19'],
#  ['/content/mchar_test_a/000915.png', '291'],
#  ['/content/mchar_test_a/000916.png', '155'],
#  ['/content/mchar_test_a/000917.png', '235'],
#  ['/content/mchar_test_a/000918.png', '53'],
#  ['/content/mchar_test_a/000919.png', '121'],
#  ['/content/mchar_test_a/000920.png', '218'],
#  ['/content/mchar_test_a/000921.png', '1122'],
#  ['/content/mchar_test_a/000922.png', '174'],
#  ['/content/mchar_test_a/000923.png', '57'],
#  ['/content/mchar_test_a/000924.png', '105'],
#  ['/content/mchar_test_a/000925.png', '221'],
#  ['/content/mchar_test_a/000926.png', '282'],
#  ['/content/mchar_test_a/000927.png', '443'],
#  ['/content/mchar_test_a/000928.png', '287'],
#  ['/content/mchar_test_a/000929.png', '69'],
#  ['/content/mchar_test_a/000930.png', '45'],
#  ['/content/mchar_test_a/000931.png', '313'],
#  ['/content/mchar_test_a/000932.png', '436'],
#  ['/content/mchar_test_a/000933.png', '32'],
#  ['/content/mchar_test_a/000934.png', '626'],
#  ['/content/mchar_test_a/000935.png', '1404'],
#  ['/content/mchar_test_a/000936.png', '730'],
#  ['/content/mchar_test_a/000937.png', '470'],
#  ['/content/mchar_test_a/000938.png', '314'],
#  ['/content/mchar_test_a/000939.png', '421'],
#  ['/content/mchar_test_a/000940.png', '65'],
#  ['/content/mchar_test_a/000941.png', '24'],
#  ['/content/mchar_test_a/000942.png', '342'],
#  ['/content/mchar_test_a/000943.png', '320'],
#  ['/content/mchar_test_a/000944.png', '147'],
#  ['/content/mchar_test_a/000945.png', '210'],
#  ['/content/mchar_test_a/000946.png', '449'],
#  ['/content/mchar_test_a/000947.png', '62'],
#  ['/content/mchar_test_a/000948.png', '63'],
#  ['/content/mchar_test_a/000949.png', '1426'],
#  ['/content/mchar_test_a/000950.png', '30'],
#  ['/content/mchar_test_a/000951.png', '19'],
#  ['/content/mchar_test_a/000952.png', '348'],
#  ['/content/mchar_test_a/000953.png', '85'],
#  ['/content/mchar_test_a/000954.png', '277'],
#  ['/content/mchar_test_a/000955.png', '253'],
#  ['/content/mchar_test_a/000956.png', '376'],
#  ['/content/mchar_test_a/000957.png', '26'],
#  ['/content/mchar_test_a/000958.png', '1538'],
#  ['/content/mchar_test_a/000959.png', '16'],
#  ['/content/mchar_test_a/000960.png', '170'],
#  ['/content/mchar_test_a/000961.png', '54'],
#  ['/content/mchar_test_a/000962.png', '130'],
#  ['/content/mchar_test_a/000963.png', '54'],
#  ['/content/mchar_test_a/000964.png', '108'],
#  ['/content/mchar_test_a/000965.png', '42'],
#  ['/content/mchar_test_a/000966.png', '371'],
#  ['/content/mchar_test_a/000967.png', '590'],
#  ['/content/mchar_test_a/000968.png', '46'],
#  ['/content/mchar_test_a/000969.png', '311'],
#  ['/content/mchar_test_a/000970.png', '72'],
#  ['/content/mchar_test_a/000971.png', '353'],
#  ['/content/mchar_test_a/000972.png', '117'],
#  ['/content/mchar_test_a/000973.png', '26'],
#  ['/content/mchar_test_a/000974.png', '862'],
#  ['/content/mchar_test_a/000975.png', '301'],
#  ['/content/mchar_test_a/000976.png', '355'],
#  ['/content/mchar_test_a/000977.png', '28'],
#  ['/content/mchar_test_a/000978.png', '8'],
#  ['/content/mchar_test_a/000979.png', '44'],
#  ['/content/mchar_test_a/000980.png', '139'],
#  ['/content/mchar_test_a/000981.png', '768'],
#  ['/content/mchar_test_a/000982.png', '275'],
#  ['/content/mchar_test_a/000983.png', '30'],
#  ['/content/mchar_test_a/000984.png', '390'],
#  ['/content/mchar_test_a/000985.png', '60'],
#  ['/content/mchar_test_a/000986.png', '12'],
#  ['/content/mchar_test_a/000987.png', '2'],
#  ['/content/mchar_test_a/000988.png', '169'],
#  ['/content/mchar_test_a/000989.png', '97'],
#  ['/content/mchar_test_a/000990.png', '24'],
#  ['/content/mchar_test_a/000991.png', '601'],
#  ['/content/mchar_test_a/000992.png', '21'],
#  ['/content/mchar_test_a/000993.png', '187'],
#  ['/content/mchar_test_a/000994.png', '286'],
#  ['/content/mchar_test_a/000995.png', '119'],
#  ['/content/mchar_test_a/000996.png', '84'],
#  ['/content/mchar_test_a/000997.png', '2'],
#  ['/content/mchar_test_a/000998.png', '131'],
#  ['/content/mchar_test_a/000999.png', '257'],
#  ...]

# %% [markdown]
# # 新段落

# %% [markdown]
# # 新段落
